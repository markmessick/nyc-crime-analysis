# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
#import gmaps
import os
import warnings

# Import API key
from zw_config import g_key

# Ignore unnecessary gmaps warning
warnings.filterwarnings('ignore')

# %%
# Read in original CSV as new dataframe
crime_df = pd.read_csv("../crime_data/Cleaned_La_Crime_Data.csv")
crime_df
# Out:
#           DATE OCC  TIME OCC  AREA NAME Crm Cd Desc  \
# 0         7/5/2014       600    Olympic     VEHICLE
# 1         8/4/2014      1430    Central     VEHICLE
# 2        2/25/2014      1300   Wilshire     VEHICLE
# 3       11/14/2014      2300     Newton     VEHICLE
# 4       10/27/2014      1300    Olympic     VEHICLE
# ...            ...       ...        ...         ...
# 865471   6/25/2017       445   Foothill    BURGLARY
# 865472  12/14/2017       900    Pacific    BURGLARY
# 865473   2/18/2017       540    Olympic        RAPE
# 865474   8/11/2017       135  Northeast   VANDALISM
# 865475   8/16/2017      1625  Southwest   VANDALISM
#
#                                            Weapon Desc      LAT       LON
# 0                                                  NaN  34.0427 -118.2916
# 1                                                  NaN  34.0464 -118.2447
# 2                                                  NaN  34.0374 -118.3740
# ...

# %%
violence_df = crime_df.loc[
    (crime_df['Crm Cd Desc']=='RAPE')|    
    (crime_df['Crm Cd Desc']=='ASSAULT')|    
    (crime_df['Crm Cd Desc']=='BATTERY')|    
    (crime_df['Crm Cd Desc']=='ARSON')| 
    (crime_df['Crm Cd Desc']=='CRIMINAL HOMICIDE')|
    (crime_df['Crm Cd Desc']=='CRIMINAL THREATS')|    
    (crime_df['Crm Cd Desc']=='SHOTS FIRED')|    
    (crime_df['Crm Cd Desc']=='WEAPONS POSSESSION/BOMBING')|    
    (crime_df['Crm Cd Desc']=='CRUELTY TO ANIMALS')|
    (crime_df['Crm Cd Desc']=='KIDNAPPING')|
    (crime_df['Crm Cd Desc']=='LYNCHING')|
    (crime_df['Crm Cd Desc']=='HUMAN TRAFFICKING')|
    (crime_df['Crm Cd Desc']=='TELEPHONE PROPERTY - DAMAGE')|
    (crime_df['Crm Cd Desc']=='INCITING A RIOT')|
    (crime_df['Crm Cd Desc']=='MANSLAUGHTER, NEGLIGENT')]

# %%
violence_df
# Out:
#           DATE OCC  TIME OCC    AREA NAME Crm Cd Desc  \
# 9        8/25/2014      2100    Southwest     BATTERY
# 11        1/3/2014      2345       Newton     BATTERY
# 12       5/24/2014      1715      Olympic        RAPE
# 17      10/12/2014      1400      Central     ASSAULT
# 29        8/7/2014      1300  77th Street     BATTERY
# ...            ...       ...          ...         ...
# 865462    6/4/2017       900  77th Street     ASSAULT
# 865466   6/29/2017      2345      Mission     BATTERY
# 865467   7/12/2017      2230     Foothill     ASSAULT
# 865469    1/1/2017      1200      Mission        RAPE
# 865473   2/18/2017       540      Olympic        RAPE
#
#                                            Weapon Desc      LAT       LON
# 9       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  34.0000 -118.3308
# 11      STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  34.0407 -118.2468
# 12      STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  34.0728 -118.3004
# ...

# %%
pie_df = violence_df['Crm Cd Desc'].value_counts()
pie_df.plot(kind='pie', shadow=True)
plt.show()

# %%
DATE = []
for row in violence_df['DATE OCC']:
    x = row.split('/')
    DATE.append((f'{x[0]}-{x[2]}'))
DATE = pd.Series(DATE)
violence_df['Year_Month'] = DATE

# %%
violence_df#['Year_Month']#.value_counts()
# Out:
#           DATE OCC  TIME OCC    AREA NAME Crm Cd Desc  \
# 9        8/25/2014      2100    Southwest     BATTERY
# 11        1/3/2014      2345       Newton     BATTERY
# 12       5/24/2014      1715      Olympic        RAPE
# 17      10/12/2014      1400      Central     ASSAULT
# 29        8/7/2014      1300  77th Street     BATTERY
# ...            ...       ...          ...         ...
# 865462    6/4/2017       900  77th Street     ASSAULT
# 865466   6/29/2017      2345      Mission     BATTERY
# 865467   7/12/2017      2230     Foothill     ASSAULT
# 865469    1/1/2017      1200      Mission        RAPE
# 865473   2/18/2017       540      Olympic        RAPE
#
#                                            Weapon Desc      LAT       LON  \
# 9       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  34.0000 -118.3308
# 11      STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  34.0407 -118.2468
# 12      STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  34.0728 -118.3004
# ...
